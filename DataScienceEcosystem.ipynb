# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Peer Graded Assignment

# %% [markdown]
# #### This is your first peer-graded assignment

# %% [markdown]
# ## Data Science Languages
#
# 1. **Python:**
# 2. **R:**
# 3. **Julia:**
# 4. **MATLAB:**

# %% [markdown]
# ### Data Science Libraries
# - **Pandas:**
# - **NumPy:**
# - **Scikit-learn:**
# - **TensorFlow:**
# - **PyTorch:**
# - **Matplotlib:**
# - **Seaborn:**
# - **Plotly:**
# - **Spacy:**

# %% [markdown]
# ### Data Science Tools
#
# | Tool                             | Description                                   |
# |----------------------------------|-----------------------------------------------|
# | **Pandas**                       | Powerful library for data manipulation and analysis, providing data structures like DataFrame. |
# | **NumPy**                        | Fundamental package for scientific computing with support for large, multi-dimensional arrays and matrices. |
# | **Scikit-learn**                 | Simple and efficient tool for data mining and data analysis, built on NumPy, SciPy, and Matplotlib. |
# | **TensorFlow**                   | Open-source machine learning framework developed by Google, widely used for deep learning tasks. |
# | **PyTorch**                      | Open-source machine learning library developed by Facebook, known for its dynamic computational graph. |
# | **Matplotlib**                   | 2D plotting library for creating static, animated, and interactive visualizations in Python. |
# | **Seaborn**                      | High-level interface for drawing attractive statistical graphics, built on top of Matplotlib. |
# | **Plotly**                       | Versatile library for creating interactive and publication-quality graphs. |
# | **Spacy**                       | Open-source library for advanced natural language processing in Python. |

# %% [markdown]
# ### Addition
# result = 5 + 3
#
# ### Subtraction
# result = 5 - 3
#
# ### Multiplication
# result = 5 * 3
#
# ### Division
# result = 8 / 3
#
# ### Exponentiation
# result = 2 ** 3
#
# ### Modulus
# result = 15 % 4

# %%
### Addition
result = 5 + 3

### Multiplication
result = 5 * 3

# %%
minutes = 120

# Conversion factor
minutes_in_an_hour = 60
# Calculate hours
hours = minutes / minutes_in_an_hour
# Output the result
hours
# Out:
# 2.0

# %% [markdown]
# ### Objectives
# - Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
#
# - Exercise 3 - Create a markdown cell for an introduction. (1 pt)
#
# - Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
#
# - Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)
#
# - Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)
#
# - Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)
#
# - Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)
#
# - Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)
#
# - Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
#
# - Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
#
# - Exercise 12 - Share your notebook through GitHub (3 pts)
#
# - Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# Author’s name : Pramit Sawant
